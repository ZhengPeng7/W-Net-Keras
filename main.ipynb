# %%
import os
import cv2
import time
import random
import shutil
import numpy as np
import matplotlib.pyplot as plt
from keras.models import model_from_json
from utils_gen import gen_paths_img_dm, gen_var_from_paths
from utils_imgproc import norm_by_imagenet
# %matplotlib inline
plt.ioff()


# Settings
dataset = "B"
# Generate paths of (train, test) x (img, dm)
(test_img_paths, train_img_paths), (test_dm_paths, train_dm_paths) = gen_paths_img_dm(
    path_file_root='data/paths_train_val_test',
    dataset=dataset
)
# Generate raw images(normalized by imagenet rgb) and density maps
test_x, test_y = gen_var_from_paths(test_img_paths[:]), gen_var_from_paths(test_dm_paths[:], stride=2)
test_x = norm_by_imagenet(test_x)  # Normalization on raw images in test set, those of training set are in image_preprocessing below.
print('Test data size:', test_x.shape[0], test_y.shape[0], len(test_img_paths))
train_x, train_y = gen_var_from_paths(train_img_paths[:]), gen_var_from_paths(train_dm_paths[:], stride=2)
print('Train data size:', train_x.shape[0], train_y.shape[0], len(train_img_paths))
# Delete the directory for saving weights during last training.
weights_dir = 'weights_' + dataset
if os.path.exists(weights_dir):
    shutil.rmtree(weights_dir)
# Out:
# Using TensorFlow backend.
# Test data size: 316 316 316
# Train data size: 400 400 400

# %%
from keras.optimizers import Adam
from keras.utils import plot_model
from wnet import wnet
from utils_loss import MSE_BCE


# Create empty directory for saving weights during training
if os.path.exists(weights_dir):
    shutil.rmtree(weights_dir)
os.makedirs(weights_dir)

# Settings of network
os.environ["CUDA_VISIBLE_DEVICES"] = "0"
net = 'wnet'
LOSS = 'MSE_BCE'
optimizer = Adam(lr=1e-4, decay=5e-3)

# Create my model
model = wnet(input_shape=(None, None, 3))
model.compile(optimizer=optimizer, loss=MSE_BCE)
model.summary()
if not os.path.exists('models'):
    os.makedirs('models')
plot_model(model, 'models/{}.png'.format(net))
with open('./models/{}.json'.format(net), 'w') as fout:
    fout.write(model.to_json())
# Out:
# Using TensorFlow backend.
# __________________________________________________________________________________________________
# Layer (type)                    Output Shape         Param #     Connected to
# ==================================================================================================
# input_1 (InputLayer)            (None, None, None, 3 0
# __________________________________________________________________________________________________
# conv2d_1 (Conv2D)               (None, None, None, 6 1792        input_1[0][0]
# __________________________________________________________________________________________________
# activation_1 (Activation)       (None, None, None, 6 0           conv2d_1[0][0]
# __________________________________________________________________________________________________
# conv2d_2 (Conv2D)               (None, None, None, 6 36928       activation_1[0][0]
# __________________________________________________________________________________________________
# activation_2 (Activation)       (None, None, None, 6 0           conv2d_2[0][0]
# __________________________________________________________________________________________________
# max_pooling2d_1 (MaxPooling2D)  (None, None, None, 6 0           activation_2[0][0]
# __________________________________________________________________________________________________
# conv2d_3 (Conv2D)               (None, None, None, 1 73856       max_pooling2d_1[0][0]
# __________________________________________________________________________________________________
# activation_3 (Activation)       (None, None, None, 1 0           conv2d_3[0][0]
# __________________________________________________________________________________________________
# conv2d_4 (Conv2D)               (None, None, None, 1 147584      activation_3[0][0]
# __________________________________________________________________________________________________
# activation_4 (Activation)       (None, None, None, 1 0           conv2d_4[0][0]
# __________________________________________________________________________________________________
# max_pooling2d_2 (MaxPooling2D)  (None, None, None, 1 0           activation_4[0][0]
# __________________________________________________________________________________________________
# conv2d_5 (Conv2D)               (None, None, None, 2 295168      max_pooling2d_2[0][0]
# __________________________________________________________________________________________________
# activation_5 (Activation)       (None, None, None, 2 0           conv2d_5[0][0]
# __________________________________________________________________________________________________
# conv2d_6 (Conv2D)               (None, None, None, 2 590080      activation_5[0][0]
# __________________________________________________________________________________________________
# activation_6 (Activation)       (None, None, None, 2 0           conv2d_6[0][0]
# __________________________________________________________________________________________________
# conv2d_7 (Conv2D)               (None, None, None, 2 590080      activation_6[0][0]
# __________________________________________________________________________________________________
# activation_7 (Activation)       (None, None, None, 2 0           conv2d_7[0][0]
# __________________________________________________________________________________________________
# max_pooling2d_3 (MaxPooling2D)  (None, None, None, 2 0           activation_7[0][0]
# __________________________________________________________________________________________________
# conv2d_8 (Conv2D)               (None, None, None, 5 1180160     max_pooling2d_3[0][0]
# __________________________________________________________________________________________________
# activation_8 (Activation)       (None, None, None, 5 0           conv2d_8[0][0]
# __________________________________________________________________________________________________
# conv2d_9 (Conv2D)               (None, None, None, 5 2359808     activation_8[0][0]
# __________________________________________________________________________________________________
# activation_9 (Activation)       (None, None, None, 5 0           conv2d_9[0][0]
# __________________________________________________________________________________________________
# conv2d_10 (Conv2D)              (None, None, None, 5 2359808     activation_9[0][0]
# __________________________________________________________________________________________________
# activation_10 (Activation)      (None, None, None, 5 0           conv2d_10[0][0]
# __________________________________________________________________________________________________
# max_pooling2d_4 (MaxPooling2D)  (None, None, None, 5 0           activation_10[0][0]
# __________________________________________________________________________________________________
# conv2d_11 (Conv2D)              (None, None, None, 5 2359808     max_pooling2d_4[0][0]
# __________________________________________________________________________________________________
# activation_11 (Activation)      (None, None, None, 5 0           conv2d_11[0][0]
# __________________________________________________________________________________________________
# conv2d_12 (Conv2D)              (None, None, None, 5 2359808     activation_11[0][0]
# __________________________________________________________________________________________________
# activation_12 (Activation)      (None, None, None, 5 0           conv2d_12[0][0]
# __________________________________________________________________________________________________
# conv2d_13 (Conv2D)              (None, None, None, 5 2359808     activation_12[0][0]
# __________________________________________________________________________________________________
# activation_13 (Activation)      (None, None, None, 5 0           conv2d_13[0][0]
# __________________________________________________________________________________________________
# up_sampling2d_4 (UpSampling2D)  (None, None, None, 5 0           activation_13[0][0]
# __________________________________________________________________________________________________
# up_sampling2d_1 (UpSampling2D)  (None, None, None, 5 0           activation_13[0][0]
# __________________________________________________________________________________________________
# concatenate_4 (Concatenate)     (None, None, None, 1 0           activation_10[0][0]
#                                                                  up_sampling2d_4[0][0]
# __________________________________________________________________________________________________
# concatenate_1 (Concatenate)     (None, None, None, 1 0           activation_10[0][0]
#                                                                  up_sampling2d_1[0][0]
# __________________________________________________________________________________________________
# conv2d_21 (Conv2D)              (None, None, None, 2 262400      concatenate_4[0][0]
# __________________________________________________________________________________________________
# conv2d_14 (Conv2D)              (None, None, None, 2 262400      concatenate_1[0][0]
# __________________________________________________________________________________________________
# activation_21 (Activation)      (None, None, None, 2 0           conv2d_21[0][0]
# __________________________________________________________________________________________________
# activation_14 (Activation)      (None, None, None, 2 0           conv2d_14[0][0]
# __________________________________________________________________________________________________
# conv2d_22 (Conv2D)              (None, None, None, 2 590080      activation_21[0][0]
# __________________________________________________________________________________________________
# conv2d_15 (Conv2D)              (None, None, None, 2 590080      activation_14[0][0]
# __________________________________________________________________________________________________
# activation_22 (Activation)      (None, None, None, 2 0           conv2d_22[0][0]
# __________________________________________________________________________________________________
# activation_15 (Activation)      (None, None, None, 2 0           conv2d_15[0][0]
# __________________________________________________________________________________________________
# up_sampling2d_5 (UpSampling2D)  (None, None, None, 2 0           activation_22[0][0]
# __________________________________________________________________________________________________
# up_sampling2d_2 (UpSampling2D)  (None, None, None, 2 0           activation_15[0][0]
# __________________________________________________________________________________________________
# concatenate_5 (Concatenate)     (None, None, None, 5 0           activation_7[0][0]
#                                                                  up_sampling2d_5[0][0]
# __________________________________________________________________________________________________
# concatenate_2 (Concatenate)     (None, None, None, 5 0           activation_7[0][0]
#                                                                  up_sampling2d_2[0][0]
# __________________________________________________________________________________________________
# conv2d_23 (Conv2D)              (None, None, None, 1 65664       concatenate_5[0][0]
# __________________________________________________________________________________________________
# conv2d_16 (Conv2D)              (None, None, None, 1 65664       concatenate_2[0][0]
# __________________________________________________________________________________________________
# activation_23 (Activation)      (None, None, None, 1 0           conv2d_23[0][0]
# __________________________________________________________________________________________________
# activation_16 (Activation)      (None, None, None, 1 0           conv2d_16[0][0]
# __________________________________________________________________________________________________
# conv2d_24 (Conv2D)              (None, None, None, 1 147584      activation_23[0][0]
# __________________________________________________________________________________________________
# conv2d_17 (Conv2D)              (None, None, None, 1 147584      activation_16[0][0]
# __________________________________________________________________________________________________
# activation_24 (Activation)      (None, None, None, 1 0           conv2d_24[0][0]
# __________________________________________________________________________________________________
# activation_17 (Activation)      (None, None, None, 1 0           conv2d_17[0][0]
# __________________________________________________________________________________________________
# up_sampling2d_6 (UpSampling2D)  (None, None, None, 1 0           activation_24[0][0]
# __________________________________________________________________________________________________
# up_sampling2d_3 (UpSampling2D)  (None, None, None, 1 0           activation_17[0][0]
# __________________________________________________________________________________________________
# concatenate_6 (Concatenate)     (None, None, None, 2 0           activation_4[0][0]
#                                                                  up_sampling2d_6[0][0]
# __________________________________________________________________________________________________
# concatenate_3 (Concatenate)     (None, None, None, 2 0           activation_4[0][0]
#                                                                  up_sampling2d_3[0][0]
# __________________________________________________________________________________________________
# conv2d_25 (Conv2D)              (None, None, None, 6 16448       concatenate_6[0][0]
# __________________________________________________________________________________________________
# conv2d_18 (Conv2D)              (None, None, None, 6 16448       concatenate_3[0][0]
# __________________________________________________________________________________________________
# activation_25 (Activation)      (None, None, None, 6 0           conv2d_25[0][0]
# __________________________________________________________________________________________________
# activation_18 (Activation)      (None, None, None, 6 0           conv2d_18[0][0]
# __________________________________________________________________________________________________
# conv2d_26 (Conv2D)              (None, None, None, 6 36928       activation_25[0][0]
# __________________________________________________________________________________________________
# conv2d_19 (Conv2D)              (None, None, None, 6 36928       activation_18[0][0]
# __________________________________________________________________________________________________
# activation_26 (Activation)      (None, None, None, 6 0           conv2d_26[0][0]
# __________________________________________________________________________________________________
# activation_19 (Activation)      (None, None, None, 6 0           conv2d_19[0][0]
# __________________________________________________________________________________________________
# conv2d_27 (Conv2D)              (None, None, None, 3 18464       activation_26[0][0]
# __________________________________________________________________________________________________
# conv2d_20 (Conv2D)              (None, None, None, 3 18464       activation_19[0][0]
# __________________________________________________________________________________________________
# activation_27 (Activation)      (None, None, None, 3 0           conv2d_27[0][0]
# __________________________________________________________________________________________________
# activation_20 (Activation)      (None, None, None, 3 0           conv2d_20[0][0]
# __________________________________________________________________________________________________
# conv2d_28 (Conv2D)              (None, None, None, 1 33          activation_27[0][0]
# __________________________________________________________________________________________________
# multiply_1 (Multiply)           (None, None, None, 3 0           activation_20[0][0]
#                                                                  conv2d_28[0][0]
# __________________________________________________________________________________________________
# conv2d_29 (Conv2D)              (None, None, None, 1 33          multiply_1[0][0]
# ==================================================================================================
# Total params: 16,989,890
# Trainable params: 16,989,890
# Non-trainable params: 0
# __________________________________________________________________________________________________

# %%
import sys
import pandas as pd
from time import time, ctime
from utils_imgproc import image_preprocessing
from utils_callback import eval_loss, callbacks_during_train


# Settings of training
batch_size = 1
epoch = 250
val_rate = 0.5
len_train = train_x.shape[0]
num_iter = int((len_train-0.1) // batch_size + 1)
best_values = {'mae': 1e5, 'rmse': 1e5, 'sfn': 1e5, 'mape': 1e5}
losses = [[1e5, 1e5, 1e5, 1e5]]
# Settings of display
dis_idx = 16 if dataset == 'B' else 0
dis_path = test_img_paths[dis_idx]
dis_x = test_x[dis_idx]
dis_y = test_y[dis_idx]
dis_lim = (5, 35) if dataset == 'B' else (50, 150)
time_st = time()

# Training iterations
for ep in range(epoch):
    for idx_train in range(0, len_train, batch_size):
        dis_epoch = str(ep+1)+'-'+str(idx_train+1)+'_'+str(len_train)
        x, y = train_x[idx_train:idx_train+batch_size], train_y[idx_train:idx_train+batch_size]
        # Preprocessings on raw images
        x, y = image_preprocessing(x, y, flip_hor=True, brightness_shift=False)
        model.fit(x, y, batch_size=1, verbose=0)
        idx_val = (idx_train / batch_size + 1)
        # Eval losses and save models
        if idx_val % (num_iter * val_rate) == 0:
            # To see predictions during training in directory 'tmp'
#             callbacks_during_train(
#                 model, dis_x=dis_x, dis_y=dis_y, dis_path=dis_path,
#                 net=net, epoch=dis_epoch
#             )
            loss = eval_loss(model, test_x, test_y, quality=False)
            if loss[0] < 9:
                val_rate = 0.25
            if loss[0] < 7.5:
                val_rate = 0.1
            losses.append(loss)
            if (loss[0] < best_values['mae']) or (loss[0] == best_values['mae'] and loss[1] < best_values['rmse']):
                model.save_weights(os.path.join(weights_dir, '{}_best.hdf5'.format(net)))
            for idx_best in range(len(loss)):
                if loss[idx_best] < best_values[list(best_values.keys())[idx_best]]:
                    best_values[list(best_values.keys())[idx_best]] = loss[idx_best]
                    to_save = True
            if to_save:
                path_save = os.path.join(weights_dir, ''.join([
                    net,
                    '_MAE', str(round(loss[0], 3)), '_RMSE', str(round(loss[1], 3)),
                    '_SFN', str(round(loss[2], 3)), '_MAPE', str(round(loss[3], 3)),
                    '_epoch', str(ep+1), '-', str(idx_val), '.hdf5'
                ]))
                model.save_weights(path_save)
                to_save = False
        # Progress panel
        time_consuming = time() - time_st
        sys.stdout.write('In epoch {}, with MAE-RMSE-SFN-MAPE={}, time consuming={}m-{}s\r'.format(
            dis_epoch, np.round(np.array(losses)[-1, :], 2),
            int(time_consuming/60), int(time_consuming-int(time_consuming/60)*60)
        ))
        sys.stdout.flush()

# Save records
losses = np.array(losses[1:])
pd.DataFrame(losses).to_csv('{}/loss.csv'.format(weights_dir), index=False, header=['MAE', 'RMSE', 'SFN', 'MAPE'])
losses_MAE, losses_RMSE, losses_SFN, losses_MAPE = losses[:, 0], losses[:, 1], losses[:, 2], losses[:, 3]
plt.plot(losses_MAE, 'r')
plt.plot(losses_RMSE, 'b')
multiplier = int(round(dis_lim[1] / np.max(losses_SFN)))
plt.plot(losses_SFN * multiplier, 'g')
plt.legend(['MAE', 'RMSE', 'SFN*{}'.format(multiplier)])
plt.ylim(dis_lim)
plt.title('Val_losses in {} epochs'.format(epoch))
plt.savefig('{}/{}_val_loss.png'.format(weights_dir, net))
plt.show()

# Rename weights_dir by the trainging end time, to prevent the careless deletion or overwriting
end_time_of_train = '-'.join(ctime().split()[:-2])
suffix_new_dir = '_{}_{}_bestMAE{}_{}'.format(dataset, LOSS, str(round(best_values['mae'], 3)), end_time_of_train)
weights_dir_neo = 'weights'+suffix_new_dir
shutil.move('weights_{}'.format(dataset), weights_dir_neo)
# Out:
# 'weights_B_MSE_BCE_bestMAE7.846_Sat-May-18'

# %%
# Analysis on results
# dis_idx = 16 if dataset == 'B' else 0
# net = 'wnet'
# weights_dir_neo = 'weights_B_MSE_BCE_bestMAE7.846_Sat-May-18'
model = model_from_json(open('models/{}.json'.format(net), 'r').read())
model.load_weights(os.path.join(weights_dir_neo, '{}_best.hdf5'.format(net)))
ct_preds = []
ct_gts = []
for i in range(len(test_x[:])):
    if i % 100 == 0:
        print('{}/{}'.format(i, len(test_x)))
    i += 0
    test_x_display = np.squeeze(test_x[i])
    test_y_display = np.squeeze(test_y[i])
    path_test_display = test_img_paths[i]
    pred = np.squeeze(model.predict(np.expand_dims(test_x_display, axis=0)))
    ct_pred = np.sum(pred)
    ct_gt = np.sum(test_y_display)
    ct_preds.append(ct_pred)
    ct_gts.append(ct_gt)
plt.plot(ct_preds, 'r>')
plt.plot(ct_gts, 'b+')
plt.legend(['ct_preds', 'ct_gts'])
plt.title('Pred vs GT')
plt.show()
error = np.array(ct_preds) - np.array(ct_gts)
plt.plot(error)
plt.title('Pred - GT, mean = {}, MAE={}'.format(
    str(round(np.mean(error), 3)),
    str(round(np.mean(np.abs(error)), 3))
))
plt.show()
idx_max_error = np.argsort(np.abs(error))[::-1]

# Show the 5 worst samples
for worst_idx in idx_max_error[:5].tolist() + [dis_idx]:
    test_x_display = np.squeeze(test_x[worst_idx])
    test_y_display = np.squeeze(test_y[worst_idx])
    path_test_display = test_img_paths[worst_idx]
    pred = np.squeeze(model.predict(np.expand_dims(test_x_display, axis=0)))
    fg, (ax_x_ori, ax_y, ax_pred) = plt.subplots(1, 3, figsize=(20, 4))
    ax_x_ori.imshow(cv2.cvtColor(cv2.imread(path_test_display), cv2.COLOR_BGR2RGB))
    ax_x_ori.set_title('Original Image')
    ax_y.imshow(test_y_display, cmap=plt.cm.jet)
    ax_y.set_title('Ground_truth: ' + str(np.sum(test_y_display)))
    ax_pred.imshow(pred, cmap=plt.cm.jet)
    ax_pred.set_title('Prediction: ' + str(np.sum(pred)))
    plt.show()
# Out:
# 0/316
# 100/316
# 200/316
# 300/316

# %%
# Generate losses and the image quality
# model = model_from_json(open('models/{}.json'.format(net), 'r').read())
# model.load_weights('models/{}.hdf5'.format(net+'xx'))
lossMAE, lossRMSE, lossSFN, lossMAPE, PSNR, SSIM = eval_loss(
    model, test_x, test_y, quality=True
)
print(lossMAE, lossRMSE, lossSFN, lossMAPE, PSNR, SSIM)
# Out:
# 6.748001e-07 7.846479 0.06459783 12.167437 29.27380612479161 0.9308878768783413
